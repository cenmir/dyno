# %% [markdown]
# # Dyno Control Panel v4.0
#
# Manual control notebook for the Arduino dynamometer.
# Firmware sends raw HX711 values — Python handles calibration and torque calculation.
#
# ## Setup
# ```bash
# # From the project root (dyno/), create venv and install dependencies:
# uv sync
# ```
# Then in VS Code, select the `.venv` Python interpreter as the notebook kernel.

# %% [markdown]
# ## Setup & Connection

# %%
import serial
import serial.tools.list_ports
import time
import threading
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import ipywidgets as widgets

# Discover COM ports
ports = serial.tools.list_ports.comports()
port_options = {f"{p.device} - {p.description}": p.device for p in ports}

port_dropdown = widgets.Dropdown(options=port_options, description='Port:',
                                 layout=widgets.Layout(width='400px'))
display(port_dropdown)
# Out:
# Dropdown(description='Port:', layout=Layout(width='400px'), options={'COM4 - Standard Serial over Bluetooth li…

# %%
ser = None

def connect():
    global ser
    if ser and ser.is_open:
        ser.close()
    ser = serial.Serial(port_dropdown.value, 115200, timeout=1)
    time.sleep(2)
    while ser.in_waiting:
        print(ser.readline().decode().strip())
    print(f"\nConnected to {port_dropdown.value}")

def disconnect():
    global ser
    if ser and ser.is_open:
        ser.close()
        print("Disconnected.")
    else:
        print("Not connected.")

connect()
# Out:
# AS5600 connected: Yes
# HX711 initialized.
# Dyno Ready v4.0.0
# Type 'help' for available commands
#
# Connected to COM9

# %%
disconnect()
# Out:
# Disconnected.

# %%
ser_lock = threading.Lock()

def send(cmd, wait=0.3, retries=3):
    """Send a command and print the response. Auto-retries on corrupted commands."""
    with ser_lock:
        for attempt in range(retries):
            while ser.in_waiting:
                ser.read(ser.in_waiting)
            ser.write(f"{cmd}\n".encode())
            ser.flush()
            time.sleep(wait)
            lines = []
            while ser.in_waiting:
                lines.append(ser.readline().decode().strip())
            if any("Unknown command" in l for l in lines) and attempt < retries - 1:
                time.sleep(0.05)
                continue
            for line in lines:
                print(line)
            return

def read_raw():
    """Read median-filtered raw HX711 value (filtered on firmware side)."""
    with ser_lock:
        for attempt in range(3):
            while ser.in_waiting:
                ser.read(ser.in_waiting)
            ser.write(b"readLoad\n")
            ser.flush()
            time.sleep(0.6)
            line = ser.readline().decode().strip()
            try:
                return float(line)
            except ValueError:
                time.sleep(0.05)
                continue
        return 0.0

# --- Load Cell Calibration ---
# Linear model: grams = raw * load_scale + load_offset
# Last calibration: tare_raw=-580900, 549g weight at raw=-346265
tare_raw = -580900.0
load_scale = 0.002340    # g/raw unit
load_offset = 1359.2     # intercept

# Physical constants
ARM_LENGTH = 0.1     # Brake arm length in meters (MEASURE AND UPDATE!)
GRAVITY = 9.80665

def tare(n=5):
    """Zero the load cell by averaging n readings (each already median-filtered)."""
    global tare_raw, load_offset
    readings = [read_raw() for _ in range(n)]
    tare_raw = np.median(readings)
    load_offset = -tare_raw * load_scale
    print(f"Tare complete. Raw zero: {tare_raw:.0f} (std: {np.std(readings):.1f})")

def calibrate(known_weight_g, n=5):
    """Calibrate using a known weight (grams). Place weight BEFORE calling. Tare first."""
    global load_scale, load_offset
    readings = [read_raw() for _ in range(n)]
    cal_raw = np.median(readings)
    load_scale = known_weight_g / (cal_raw - tare_raw)
    load_offset = -tare_raw * load_scale
    verify = cal_raw * load_scale + load_offset
    print(f"Calibration complete.")
    print(f"  Raw zero: {tare_raw:.0f}, Raw loaded: {cal_raw:.0f}")
    print(f"  Scale: {load_scale:.6f} g/raw, Offset: {load_offset:.1f}")
    print(f"  Verify: {verify:.1f} g (should be {known_weight_g} g)")

def get_load_grams():
    """Get current load in grams."""
    return read_raw() * load_scale + load_offset

def get_load_kg():
    return get_load_grams() / 1000.0

def get_torque():
    return get_load_kg() * GRAVITY * ARM_LENGTH

def read_load():
    """Read and display load, force, and torque."""
    kg = get_load_kg()
    force = kg * GRAVITY
    torque = force * ARM_LENGTH
    print(f"Load: {kg:.4f} kg | Force: {force:.4f} N | Torque: {torque:.4f} Nm")

print("Load cell ready with saved calibration. Re-run tare() + calibrate() if needed.")
# Out:
# Load cell ready with saved calibration. Re-run tare() + calibrate() if needed.

# %% [markdown]
# ## Motor Power

# %%
send("enable")
# Out:
# OK

# %%
send("disable")
# Out:
# OK

# %%
# EMERGENCY STOP
send("stop")

# %% [markdown]
# ## Test Motor Control

# %%
rpm_slider = widgets.IntSlider(value=0, min=0, max=400, step=10, description='RPM:',
                               continuous_update=False, style={'description_width': '50px'},
                               layout=widgets.Layout(width='400px'))
rpm_output = widgets.Output()

def on_rpm_change(change):
    with rpm_output:
        rpm_output.clear_output()
        send(f"setRPM {change['new']}")

rpm_slider.observe(on_rpm_change, names='value')
display(rpm_slider, rpm_output)
# Out:
# IntSlider(value=0, continuous_update=False, description='RPM:', layout=Layout(width='400px'), max=400, step=10…
# Output()

# %%
send("setRPM 0")  # Stop motor
# Out:
# OK

# %%
send("readRPM")
# Out:
# 191.42

# %% [markdown]
# ## Brake Control

# %%
send("brakeApply")
# Out:
# 35000

# %%
send("brake 100")  # Move brake by steps (+apply / -release)

# %%
send("brakeMove 1")  # Move brake by mm

# %%
send("brakeHome")
# Out:
# OK

# %% [markdown]
# ## Load Cell
#
# Calibration is done in Python. Steps:
# 1. Remove all weight from the load cell
# 2. Run `tare()`
# 3. Place a known weight (e.g. 500g) on the load cell
# 4. Run `calibrate(500)` (replace 500 with your weight in grams)

# %%
send("debug")

# %%
tare()

# %%
calibrate(549)  # <-- Replace 500 with your known weight in grams

# %%
read_load()

# %%
print(f"Raw: {read_raw():.0f} | Offset: {load_offset:.0f} | Scale: {load_scale:.6f}")

# %% [markdown]
# ## Sensors & Debug

# %%
send("debug")
# Out:
# angle:2626,steps/s:0,rpm:0.00,hx_ready:0,hx_read:-589564,load_raw:-580215

# %%
send("status")
# Out:
# 0.0,0.0,-590925,0,0

# %%
send("readRPM")
# Out:
# -299.72

# %%
# Continuous RPM reader — displays live RPM in the output area
rpm_stop_event = threading.Event()
rpm_output = widgets.Output()
display(rpm_output)

def read_rpm_loop():
    while not rpm_stop_event.is_set():
        try:
            with ser_lock:
                while ser.in_waiting:
                    ser.read(ser.in_waiting)
                ser.write(b"status\n")
                ser.flush()
                time.sleep(0.3)
                lines = []
                while ser.in_waiting:
                    lines.append(ser.readline().decode().strip())
            with rpm_output:
                clear_output(wait=True)
                for line in lines:
                    print(line)
        except Exception as e:
            with rpm_output:
                clear_output(wait=True)
                print(f"Error: {e}")
            break
        time.sleep(0.2)

rpm_stop_event.clear()
rpm_thread = threading.Thread(target=read_rpm_loop, daemon=True)
rpm_thread.start()
print("RPM monitor started. Run next cell to stop.")
# Out:
# Output()
# RPM monitor started. Run next cell to stop.

# %%
# Stop RPM monitor
rpm_stop_event.set()
rpm_thread.join(timeout=2)
print("RPM monitor stopped.")
# Out:
# RPM monitor stopped.

# %% [markdown]
# # Automatic testing

# %%
import csv
import os
import datetime
from dataclasses import dataclass, field
from typing import List

RESULTS_DIR = os.path.join(os.path.dirname(os.path.abspath("__file__")), "results")

def send_cmd(cmd, wait=0.3, retries=3):
    """Send command and return response string (no printing)."""
    with ser_lock:
        for attempt in range(retries):
            while ser.in_waiting:
                ser.read(ser.in_waiting)
            ser.write(f"{cmd}\n".encode())
            ser.flush()
            time.sleep(wait)
            lines = []
            while ser.in_waiting:
                lines.append(ser.readline().decode().strip())
            response = "\n".join(lines)
            if "Unknown command" in response and attempt < retries - 1:
                time.sleep(0.05)
                continue
            return response
    return ""

def parse_status():
    """Send 'status' and return dict with rpm, targetRPM, rawLoad, brakePos, brakeMoving.
    Returns None on parse failure."""
    resp = send_cmd("status")
    parts = resp.strip().split(",")
    if len(parts) != 5:
        return None
    try:
        return {
            "rpm": float(parts[0]),
            "targetRPM": float(parts[1]),
            "rawLoad": float(parts[2]),
            "brakePos": int(parts[3]),
            "brakeMoving": int(parts[4]),
        }
    except ValueError:
        return None

def raw_to_torque(raw):
    """Convert raw HX711 value to torque (Nm) using Python-side calibration."""
    grams = raw * load_scale + load_offset
    kg = grams / 1000.0
    return kg * GRAVITY * ARM_LENGTH

print("Test helpers loaded.")
# Out:
# Test helpers loaded.

# %%
def ramp_up(target_rpm, timeout=10, stable_window=2.0, stable_threshold=None):
    """Set motor to target_rpm and wait for stabilization with live graph.

    Args:
        target_rpm: Desired RPM setpoint
        timeout: Max seconds to wait for stabilization
        stable_window: Seconds of consecutive stable readings required
        stable_threshold: RPM must be within this of target (default: 10% of target)

    Returns:
        bool: True if stabilized, False if timed out
    """
    if stable_threshold is None:
        stable_threshold = target_rpm * 0.10

    send_cmd(f"setRPM {target_rpm}")

    times = []
    rpms = []
    t0 = time.time()
    out = widgets.Output()
    display(out)

    while True:
        elapsed = time.time() - t0
        if elapsed > timeout:
            with out:
                clear_output(wait=True)
                print(f"Timed out after {timeout}s. Last RPM: {rpms[-1]:.1f}" if rpms else "No readings")
            return False

        s = parse_status()
        if s is None:
            time.sleep(0.1)
            continue

        times.append(elapsed)
        rpms.append(abs(s["rpm"]))

        # Check stability: all readings in the last stable_window seconds within threshold
        stable = False
        if elapsed >= stable_window:
            cutoff = elapsed - stable_window
            recent = [r for t, r in zip(times, rpms) if t >= cutoff]
            if all(abs(r - target_rpm) < stable_threshold for r in recent):
                stable = True

        # Live plot
        with out:
            clear_output(wait=True)
            fig, ax = plt.subplots(figsize=(8, 3))
            ax.axhline(y=target_rpm, color='r', linestyle='--', label=f'Setpoint ({target_rpm} RPM)')
            ax.plot(times, rpms, 'b-', linewidth=1.5, label='Actual RPM')
            ax.set_xlabel('Time (s)')
            ax.set_ylabel('RPM')
            ax.set_title(f'Ramp-up: {rpms[-1]:.0f} / {target_rpm} RPM' +
                         (' — STABLE' if stable else ''))
            ax.legend(loc='lower right')
            ax.set_ylim(0, target_rpm * 1.3)
            ax.grid(True, alpha=0.3)
            plt.tight_layout()
            plt.show()

        if stable:
            return True

        time.sleep(0.2)

print("ramp_up() defined.")
# Out:
# ramp_up() defined.

# %%
test_abort = threading.Event()

@dataclass
class TestResult:
    """Result of a single brake test run."""
    test_id: str
    setpoint_rpm: float
    max_torque_nm: float
    rpm_at_max_torque: float
    timeseries: List[dict] = field(default_factory=list)

def wait_brake_done(timeout=30):
    """Poll status until brake motor stops moving."""
    t0 = time.time()
    while time.time() - t0 < timeout:
        s = parse_status()
        if s and s["brakeMoving"] == 0:
            return
        time.sleep(0.3)
    print("WARNING: Brake motor did not stop within timeout")

def brake_test(target_rpm, brake_step=1000, stall_rpm=5, stall_count=3):
    """Apply brake progressively until motor stalls. Shows live RPM + torque graph.

    Args:
        target_rpm: RPM setpoint (motor should already be running)
        brake_step: Brake steps to advance each iteration (1000 ~ 1s of motor travel)
        stall_rpm: RPM threshold for stall detection
        stall_count: Consecutive readings below stall_rpm to confirm stall

    Returns:
        TestResult with peak torque data and full timeseries
    """
    test_abort.clear()
    test_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    max_torque = 0.0
    rpm_at_max = target_rpm  # Use setpoint RPM since measured RPM is noisy near stall
    consecutive_stalls = 0
    total_brake_steps = 0
    timeseries = []
    t0 = time.time()

    # Abort button
    abort_btn = widgets.Button(description="ABORT TEST", button_style='danger',
                               layout=widgets.Layout(width='200px', height='40px'))
    abort_btn.on_click(lambda _: test_abort.set())
    out = widgets.Output()
    display(abort_btn, out)

    try:
        while True:
            if test_abort.is_set():
                print("Test aborted by user!")
                break

            # Apply incremental brake (non-blocking on firmware side)
            send_cmd(f"brake {brake_step}")
            total_brake_steps += brake_step

            # Poll status while brake motor is moving (~1s at 1000 steps/s)
            for _ in range(3):
                if test_abort.is_set():
                    break
                s = parse_status()
                if s is None:
                    continue

                rpm = abs(s["rpm"])
                torque = raw_to_torque(s["rawLoad"])
                elapsed = time.time() - t0

                timeseries.append({
                    "t": elapsed, "rpm": rpm,
                    "torque": torque, "brake_pos": s["brakePos"]
                })

                if torque > max_torque:
                    max_torque = torque

                # Stall detection
                if rpm < stall_rpm:
                    consecutive_stalls += 1
                else:
                    consecutive_stalls = 0

                if consecutive_stalls >= stall_count:
                    break

            # Live dual-axis plot
            if timeseries:
                ts_t = [p["t"] for p in timeseries]
                ts_rpm = [p["rpm"] for p in timeseries]
                ts_torque = [p["torque"] for p in timeseries]

                with out:
                    clear_output(wait=True)
                    fig, ax1 = plt.subplots(figsize=(10, 4))
                    ax1.set_xlabel('Time (s)')
                    ax1.set_ylabel('RPM', color='tab:blue')
                    ax1.plot(ts_t, ts_rpm, 'b-', linewidth=1.5, label='RPM')
                    ax1.tick_params(axis='y', labelcolor='tab:blue')
                    ax1.set_ylim(bottom=0)

                    ax2 = ax1.twinx()
                    ax2.set_ylabel('Torque (Nm)', color='tab:red')
                    ax2.plot(ts_t, ts_torque, 'r-', linewidth=1.5, label='Torque')
                    ax2.axhline(y=max_torque, color='r', linestyle=':', alpha=0.5,
                                label=f'Max: {max_torque:.4f} Nm')
                    ax2.tick_params(axis='y', labelcolor='tab:red')
                    ax2.set_ylim(bottom=0)

                    ax1.set_title(f'Brake Test @ {target_rpm} RPM | '
                                  f'Max Torque: {max_torque:.4f} Nm')
                    fig.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))
                    fig.tight_layout()
                    plt.show()

            if consecutive_stalls >= stall_count:
                print(f"Stall detected! Max torque: {max_torque:.4f} Nm at {target_rpm} RPM (setpoint)")
                break

    finally:
        # Always stop motor and retract brake fully
        send_cmd("setRPM 0")
        if total_brake_steps > 0:
            print(f"Retracting brake ({total_brake_steps} steps)...")
            send_cmd(f"brake -{total_brake_steps}")
            wait_brake_done()
        send_cmd("brakeHome")
        abort_btn.disabled = True
        print("Brake homed.")

    return TestResult(test_id, target_rpm, max_torque, rpm_at_max, timeseries)

print("brake_test() defined.")

# %%
def get_csv_path(motor_id):
    """Get path to results CSV for a given motor."""
    return os.path.join(RESULTS_DIR, f"dyno_results_{motor_id}.csv")

def save_result(result, motor_id):
    """Append test result to CSV. Creates file with header if it doesn't exist."""
    os.makedirs(RESULTS_DIR, exist_ok=True)
    csv_path = get_csv_path(motor_id)
    file_exists = os.path.isfile(csv_path)

    with open(csv_path, "a", newline="") as f:
        writer = csv.writer(f)
        if not file_exists:
            writer.writerow([f"# Motor: {motor_id}"])
            writer.writerow(["test_id", "setpoint_rpm", "max_torque_nm", "rpm_at_max_torque"])
        writer.writerow([
            result.test_id,
            result.setpoint_rpm,
            f"{result.max_torque_nm:.6f}",
            f"{result.rpm_at_max_torque:.2f}",
        ])
    print(f"Result saved to {csv_path}")

def run_test(target_rpm, motor_id="NEMA17_default"):
    """Full automated test: enable, ramp up, brake until stall, save CSV, disable.

    Args:
        target_rpm: RPM setpoint for the test
        motor_id: Identifier for the motor under test (used in CSV filename)

    Returns:
        TestResult
    """
    print(f"=== Starting test: {target_rpm} RPM, Motor: {motor_id} ===")

    # Enable motors and home brake
    send_cmd("enable")
    send_cmd("brakeHome")
    time.sleep(0.5)

    # Ramp up to target RPM
    stable = ramp_up(target_rpm)
    if not stable:
        print("WARNING: Motor did not stabilize within timeout. Proceeding anyway.")

    # Run brake test
    result = brake_test(target_rpm)

    # Save to CSV
    save_result(result, motor_id)

    # Disable motors
    send_cmd("disable")

    print(f"\n=== Test complete ===")
    print(f"Max torque: {result.max_torque_nm:.4f} Nm at {result.rpm_at_max_torque:.1f} RPM")
    return result

print("run_test() and CSV helpers defined.")
# Out:
# run_test() and CSV helpers defined.

# %% [markdown]
# ## Test begins here
#
# Ändra rpm och kör

# %%
# === Configure and run a test ===
MOTOR_ID = "NEMA17_A"       # Change this for each motor you test
TEST_RPM = 200               # RPM setpoint

result = run_test(TEST_RPM, MOTOR_ID)
# Out:
# === Starting test: 200 RPM, Motor: NEMA17_A ===
# Output()
# WARNING: Motor did not stabilize within timeout. Proceeding anyway.
# Button(button_style='danger', description='ABORT TEST', layout=Layout(height='40px', width='200px'), style=But…
# Output()
# Stall detected! Max torque: 0.5840 Nm at 4 RPM
# Result saved to d:\Dropbox\Work\Kurser\Konstruktion1\HT25\Arduino\Dyno\tools\results\dyno_results_NEMA17_A.csv
#
# === Test complete ===
# Max torque: 0.5840 Nm at 4.0 RPM

# %%
def load_results(motor_id):
    """Load all test results from CSV. Returns list of dicts."""
    csv_path = get_csv_path(motor_id)
    if not os.path.isfile(csv_path):
        print(f"No results file found: {csv_path}")
        return []

    results = []
    with open(csv_path, "r") as f:
        reader = csv.reader(f)
        for row in reader:
            if not row or row[0].startswith("#") or row[0] == "test_id":
                continue
            results.append({
                "test_id": row[0],
                "setpoint_rpm": float(row[1]),
                "max_torque_nm": float(row[2]),
                "rpm_at_max_torque": float(row[3]),
            })
    return results

def plot_results(motor_id):
    """Plot test results from CSV. One subplot per RPM setpoint + combined curve."""
    results = load_results(motor_id)
    if not results:
        return

    # Group by setpoint RPM
    rpm_groups = {}
    for r in results:
        rpm = r["setpoint_rpm"]
        rpm_groups.setdefault(rpm, []).append(r)

    sorted_rpms = sorted(rpm_groups.keys())

    # One subplot per RPM setpoint
    n = len(sorted_rpms)
    fig, axes = plt.subplots(1, max(n, 1), figsize=(5 * n, 4), squeeze=False)
    for i, rpm in enumerate(sorted_rpms):
        ax = axes[0][i]
        group = rpm_groups[rpm]
        torques = [r["max_torque_nm"] for r in group]
        test_ids = [r["test_id"] for r in group]
        x = range(1, len(torques) + 1)
        ax.bar(x, torques, color='steelblue', alpha=0.8)
        ax.set_xlabel("Test #")
        ax.set_ylabel("Max Torque (Nm)")
        ax.set_title(f"{rpm:.0f} RPM (n={len(group)})")
        ax.set_xticks(list(x))
        ax.set_ylim(bottom=0)
        ax.grid(True, alpha=0.3, axis='y')
    fig.suptitle(f"Test Results: {motor_id}", fontsize=14)
    plt.tight_layout()
    plt.show()

    # Combined torque-speed curve (mean torque per RPM)
    if len(sorted_rpms) > 1:
        mean_torques = [np.mean([r["max_torque_nm"] for r in rpm_groups[rpm]]) for rpm in sorted_rpms]
        fig2, ax2 = plt.subplots(figsize=(8, 5))
        ax2.plot(sorted_rpms, mean_torques, 'bo-', markersize=8, linewidth=2)
        # Also plot individual points
        for rpm in sorted_rpms:
            torques = [r["max_torque_nm"] for r in rpm_groups[rpm]]
            ax2.scatter([rpm] * len(torques), torques, color='lightblue',
                        edgecolors='steelblue', s=40, zorder=5)
        ax2.set_xlabel("RPM Setpoint")
        ax2.set_ylabel("Max Torque (Nm)")
        ax2.set_title(f"Torque-Speed Curve: {motor_id}")
        ax2.set_xlim(left=0)
        ax2.set_ylim(bottom=0)
        ax2.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()

print("plot_results() defined.")
# Out:
# plot_results() defined.

# %%
# === Plot all results for a motor ===
plot_results("NEMA17_A")
